# %% [markdown]
# # WeatherPy: An Analysis of World Weather Data using OpenWeatherMap API Citipy, Pandas, & Matplotlib
# UCIRV201902DATA3 <br>
# Submitted by K. Harrison <br>
# 02-APR-2019
#
# #### Skills
# Python, API Scraping, JSON, Citipy, Pandas, Numpy, Matplotlib/Plotly,

# %% [markdown]
# ___
# ## Data Wrangling

# %% [markdown]
# ### Background
# Current weather data, including temperature, humtidy, windspeed, and cloudiness, is sampled for 1500 random cities using the OpenWeatherMap API.  The data is plotted to determine the relationships between the cities location (latitude) and the weather variables to determine trends.

# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import datetime
from citipy import citipy
from config import api_key

# %% [markdown]
# ### Citipy
# Use citipy library to convert random coordiantes to nearest cities.

# %%
#generate random numbers for latitude and longitude coordinates; zip into list
lat = np.random.uniform(-90, 90, size=10000)
lon = np.random.uniform(-180, 180, size=10000)
coordinates = zip(lat, lon)

#using citipy, find the the nearest city to the coordinates
cities = []
for coordinate_pair in coordinates:
    lat, lon = coordinate_pair
    cities.append(citipy.nearest_city(lat, lon))
    
#initialize city_names list to store citipy data
city_names = []

#store actual city names into new list for only unique values
for city in cities:
        name = city.city_name
        name = name.title()
        if name not in city_names:
            city_names.append(name)

# %% [markdown]
# ### OpenWeatherMap API Scraping
# Call on OpenWeatherMap API to gather weather data from around the world and print log.

# %%
#set base url and units for API call
base_url = 'http://api.openweathermap.org/data/2.5/weather?q='
units = 'imperial'

#initialize variable counter; city_data dictionary to store weather data
counter = 0
city_data = {}

#record start time of api calls; format print output
api_start = datetime.datetime.now()
print('-------------------------------------------------')
print(f'Time at Beginning API Calls: {api_start.strftime("%Y-%m-%d %H:%M")}')
print('-------------------------------------------------')
      
#call on api using each city name
for city in city_names:
    if counter < 1500: #set number of cities to return
        url = f'{base_url}{city}&APPID={api_key}&units={units}' #append base_url with city name
        request = requests.get(url).json() #get request
      
        #determine if city name is a part of OWM (request will return 200 if found)  
        if request['cod'] == 200: 
            print(f'Record {counter + 1}:')
            
            #store city data into dictionary
            city_data[city] = {}
            city_data[city]['Latitude'] = request['coord']['lat']
            city_data[city]['Longitude'] = request['coord']['lon']
            city_data[city]['Current Temp F'] = request['main']['temp']
            city_data[city]['Max Temp F'] = request['main']['temp_max']
            city_data[city]['Humitidy %'] = request['main']['humidity']
            city_data[city]['Cloudiness %'] = request['clouds']['all']
            city_data[city]['Wind Speed'] = request['wind']['speed']
            city_data[city]['Country'] = request['sys']['country']
            country = request['sys']['country']
            print(f'     Data retrieved for {city}, {country}')
            counter +=1
      
        #if city cannot be found in OWM, print statement and skip to next.
        else:
            print(f"{city} cannot be found. Skipping to next city.")

#once calls are complete, store end time and calculate duration    
api_end = datetime.datetime.now()
api_duration = (api_end - api_start).total_seconds()

#print time info to log
print('-------------------------------------------------')
print(f'Time at End of API Calls: {api_end.strftime("%Y-%m-%d %H:%M")}')
print(f'The API Calls took {round(api_duration)} seconds.')
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Time at Beginning API Calls: 2019-03-24 23:24
# -------------------------------------------------
# Record 1:
#      Data retrieved for Ambon, FR
# Record 2:
#      Data retrieved for Umm Lajj, SA
# Sentyabrskiy cannot be found. Skipping to next city.
# Record 3:
#      Data retrieved for Hobyo, SO
# Record 4:
#      Data retrieved for Chifeng, CN
# Record 5:
#      Data retrieved for Cidreira, BR
# Record 6:
#      Data retrieved for Sorong, ID
# Record 7:
#      Data retrieved for Laurel, US
# Record 8:
#      Data retrieved for Kapaa, US
# Record 9:
#      Data retrieved for Tasiilaq, GL
# Record 10:
#      Data retrieved for Khatanga, RU
# Record 11:
#      Data retrieved for Galveston, US
# Asau cannot be found. Skipping to next city.
# Record 12:
#      Data retrieved for Punta Arenas, CL
# Record 13:
#      Data retrieved for Necochea, AR
# Korla cannot be found. Skipping to next city.
# Record 14:
#      Data retrieved for Kaohsiung, TW
# Record 15:
#      Data retrieved for Esperance, TT
# Record 16:
#      Data retrieved for Hervey Bay, AU
# Record 17:
#      Data retrieved for Solnechnyy, RU
# Record 18:
#      Data retrieved for Sao Jose Da Coroa Grande, BR
# Record 19:
#      Data retrieved for Baffa, PK
# Record 20:
#      Data retrieved for Iznoski, RU
# Record 21:
#      Data retrieved for Marawi, PH
# Record 22:
#      Data retrieved for Poum, MK
# Record 23:
#      Data retrieved for Port Elizabeth, US
# Taolanaro cannot be found. Skipping to next city.
# Record 24:
#      Data retrieved for Jamestown, AU
# Record 25:
#      Data retrieved for Mataura, NZ
# Record 26:
#      Data retrieved for Geraldton, CA
# Record 27:
#      Data retrieved for Phalodi, IN
# Record 28:
#      Data retrieved for Paraguacu, BR
# Amderma cannot be found. Skipping to next city.
# Record 29:
#      Data retrieved for Buchanan, LR
# Record 30:
#      Data retrieved for Manaus, BR
# Record 31:
#      Data retrieved for East London, ZA
# Gorno-Chuyskiy cannot be found. Skipping to next city.
# Record 32:
#      Data retrieved for Kurumkan, RU
# Record 33:
#      Data retrieved for Vostok, RU
# Record 34:
#      Data retrieved for Cherskiy, RU
# Ituni cannot be found. Skipping to next city.
# Record 35:
#      Data retrieved for Mandalgovi, MN
# Bairiki cannot be found. Skipping to next city.
# Record 36:
#      Data retrieved for Puerto Ayora, EC
# Record 37:
#      Data retrieved for Clyde River, CA
# Record 38:
#      Data retrieved for New Norfolk, AU
# Record 39:
#      Data retrieved for Pangnirtung, CA
# Record 40:
#      Data retrieved for Hermanus, ZA
# Record 41:
#      Data retrieved for Avarua, CK
# Record 42:
#      Data retrieved for Ponta Do Sol, BR
# Record 43:
#      Data retrieved for Dikson, RU
# Record 44:
#      Data retrieved for Saint-Georges, CA
# Record 45:
#      Data retrieved for Harindanga, IN
# Record 46:
#      Data retrieved for Bambous Virieux, MU
# Record 47:
#      Data retrieved for Torbay, CA
# Record 48:
#      Data retrieved for Lebu, ET
# Record 49:
#      Data retrieved for Sur, OM
# Galiwinku cannot be found. Skipping to next city.
# Record 50:
#      Data retrieved for Broken Hill, AU
# Record 51:
#      Data retrieved for Olinda, EC
# Record 52:
#      Data retrieved for Gotsu, JP
# Grand River South East cannot be found. Skipping to next city.
# Record 53:
#      Data retrieved for Pasighat, IN
# Record 54:
#      Data retrieved for Ayan, TR
# Record 55:
#      Data retrieved for Fairbanks, US
# Record 56:
#      Data retrieved for Qaanaaq, GL
# Record 57:
#      Data retrieved for Port Alfred, ZA
# Record 58:
#      Data retrieved for Albany, US
# Record 59:
#      Data retrieved for Barrow, AR
# Record 60:
#      Data retrieved for Upernavik, GL
# Record 61:
#      Data retrieved for Port Blair, IN
# Record 62:
#      Data retrieved for Mumford, GH
# Record 63:
#      Data retrieved for Tiksi, RU
# Illoqqortoormiut cannot be found. Skipping to next city.
# Banmo cannot be found. Skipping to next city.
# Vaitupu cannot be found. Skipping to next city.
# Record 64:
#      Data retrieved for Pyaozerskiy, RU
# Record 65:
#      Data retrieved for Vaini, IN
# Record 66:
#      Data retrieved for Bredasdorp, ZA
# Record 67:
#      Data retrieved for Kenai, US
# Record 68:
#      Data retrieved for Busselton, AU
# Record 69:
#      Data retrieved for Araouane, ML
# Record 70:
#      Data retrieved for Rikitea, PF
# Record 71:
#      Data retrieved for Vanimo, PG
# Record 72:
#      Data retrieved for Ushuaia, AR
# Record 73:
#      Data retrieved for Yaan, NG
# Record 74:
#      Data retrieved for Hilo, US
# Metehara cannot be found. Skipping to next city.
# Record 75:
#      Data retrieved for Faanui, PF
# Record 76:
#      Data retrieved for Aykhal, RU
# Record 77:
#      Data retrieved for Hamilton, CA
# Record 78:
#      Data retrieved for Nome, US
# Record 79:
#      Data retrieved for Salta, AR
# Record 80:
#      Data retrieved for Castro, CL
# Record 81:
#      Data retrieved for Fairlie, US
# Record 82:
#      Data retrieved for Tuktoyaktuk, CA
# Record 83:
#      Data retrieved for Airai, TL
# Record 84:
#      Data retrieved for San Cristobal, EC
# Record 85:
#      Data retrieved for Alihe, CN
# Record 86:
#      Data retrieved for Bakchar, RU
# Record 87:
#      Data retrieved for Broome, GB
# Record 88:
#      Data retrieved for Qaqortoq, GL
# Record 89:
#      Data retrieved for Mar Del Plata, AR
# Record 90:
#      Data retrieved for Richmond, CA
# Record 91:
#      Data retrieved for Mount Gambier, AU
# Record 92:
#      Data retrieved for Sawtell, AU
# Record 93:
#      Data retrieved for Yarmouth, GB
# Record 94:
#      Data retrieved for Saldanha, PT
# Record 95:
#      Data retrieved for Tura, IN
# Record 96:
#      Data retrieved for Iqaluit, CA
# Record 97:
#      Data retrieved for Langfang, CN
# Record 98:
#      Data retrieved for Nalut, LY
# Record 99:
#      Data retrieved for Innisfail, CA
# Record 100:
#      Data retrieved for Tateyama, JP
# Record 101:
#      Data retrieved for Christchurch, NZ
# Record 102:
#      Data retrieved for Capitan Bado, PY
# Tsienyane cannot be found. Skipping to next city.
# Record 103:
#      Data retrieved for Sankheda, IN
# Record 104:
#      Data retrieved for Tautira, PF
# Record 105:
#      Data retrieved for Ketchikan, US
# Record 106:
#      Data retrieved for Cape Town, ZA
# Record 107:
#      Data retrieved for Presidencia Roque Saenz Pena, AR
# Record 108:
#      Data retrieved for Kargasok, RU
# Belushya Guba cannot be found. Skipping to next city.
# Yunjinghong cannot be found. Skipping to next city.
# Record 109:
#      Data retrieved for Samarai, PG
# Record 110:
#      Data retrieved for Ribeira Grande, PT
# Record 111:
#      Data retrieved for Kalangala, UG
# Samusu cannot be found. Skipping to next city.
# Record 112:
#      Data retrieved for Georgetown, GY
# Record 113:
#      Data retrieved for Yellowknife, CA
# Record 114:
#      Data retrieved for Cabo San Lucas, MX
# Record 115:
#      Data retrieved for Anadyr, RU
# Record 116:
#      Data retrieved for Makakilo City, US
# Record 117:
#      Data retrieved for Lagoa, PT
# Yirol cannot be found. Skipping to next city.
# Record 118:
#      Data retrieved for Thunder Bay, CA
# Record 119:
#      Data retrieved for Chuy, UY
# Record 120:
#      Data retrieved for Atuona, PF
# Record 121:
#      Data retrieved for Kamaishi, JP
# Record 122:
#      Data retrieved for Srednekolymsk, RU
# Record 123:
#      Data retrieved for Kavieng, PG
# Record 124:
#      Data retrieved for Ati, TD
# Record 125:
#      Data retrieved for Xinzhou, CN
# Record 126:
#      Data retrieved for Marzuq, YE
# Record 127:
#      Data retrieved for Petropavlovsk-Kamchatskiy, RU
# Tsihombe cannot be found. Skipping to next city.
# Record 128:
#      Data retrieved for Rocha, UY
# Record 129:
#      Data retrieved for San Antonio, CL
# Record 130:
#      Data retrieved for Hirara, JP
# Record 131:
#      Data retrieved for Chokurdakh, RU
# Record 132:
#      Data retrieved for Nizhniy Tsasuchey, RU
# Record 133:
#      Data retrieved for Kashirskoye, RU
# Record 134:
#      Data retrieved for Touros, BR
# Record 135:
#      Data retrieved for Saint-Philippe, CA
# Record 136:
#      Data retrieved for Mahebourg, MU
# Record 137:
#      Data retrieved for Zaraza, VE
# Tumannyy cannot be found. Skipping to next city.
# Record 138:
#      Data retrieved for Matamoros, US
# Record 139:
#      Data retrieved for Pudozh, RU
# Record 140:
#      Data retrieved for Arman, RU
# Record 141:
#      Data retrieved for San Patricio, PY
# Record 142:
#      Data retrieved for Arak, IR
# Record 143:
#      Data retrieved for Marienburg, DE
# Record 144:
#      Data retrieved for Victoria, BN
# Record 145:
#      Data retrieved for Saint George, GR
# Record 146:
#      Data retrieved for Ahipara, NZ
# Record 147:
#      Data retrieved for Souillac, FR
# Record 148:
#      Data retrieved for Beloha, MG
# Record 149:
#      Data retrieved for Hobart, AU
# Record 150:
#      Data retrieved for Chimore, BO
# Kazalinsk cannot be found. Skipping to next city.
# Attawapiskat cannot be found. Skipping to next city.
# Record 151:
#      Data retrieved for Garissa, KE
# Record 152:
#      Data retrieved for Sao Filipe, CV
# Sorvag cannot be found. Skipping to next city.
# Record 153:
#      Data retrieved for Pevek, RU
# Record 154:
#      Data retrieved for Bluff, AU
# Record 155:
#      Data retrieved for Kogon, UZ
# Record 156:
#      Data retrieved for Lokosovo, RU
# Record 157:
#      Data retrieved for Aras, YE
# Record 158:
#      Data retrieved for Osmanabad, IN
# Record 159:
#      Data retrieved for Provideniya, RU
# Marcona cannot be found. Skipping to next city.
# Record 160:
#      Data retrieved for Prieska, ZA
# Record 161:
#      Data retrieved for Gwadar, PK
# Record 162:
#      Data retrieved for Conde, BR
# Record 163:
#      Data retrieved for Husavik, CA
# Record 164:
#      Data retrieved for Marmato, CO
# Umzimvubu cannot be found. Skipping to next city.
# Record 165:
#      Data retrieved for Moranbah, AU
# Record 166:
#      Data retrieved for Adrar, DZ
# Record 167:
#      Data retrieved for Poste De Flacq, MU
# Cheuskiny cannot be found. Skipping to next city.
# Record 168:
#      Data retrieved for Mubende, UG
# Record 169:
#      Data retrieved for Tubuala, PA
# Record 170:
#      Data retrieved for Narsaq, GL
# Olafsvik cannot be found. Skipping to next city.
# Record 171:
#      Data retrieved for Amparo, BR
# Record 172:
#      Data retrieved for Saint-Augustin, FR
# Record 173:
#      Data retrieved for Merauke, ID
# Record 174:
#      Data retrieved for Manicore, BR
# Record 175:
#      Data retrieved for Chicama, PE
# Record 176:
#      Data retrieved for Harper, US
# Record 177:
#      Data retrieved for Huinan, CN
# Record 178:
#      Data retrieved for Saquena, PE
# Record 179:
#      Data retrieved for Severo-Kurilsk, RU
# Record 180:
#      Data retrieved for Klaksvik, FO
# Record 181:
#      Data retrieved for Batemans Bay, AU
# Record 182:
#      Data retrieved for Lensk, RU
# Record 183:
#      Data retrieved for Tsabong, BW
# Record 184:
#      Data retrieved for Lata, IN
# Record 185:
#      Data retrieved for Berja, ES
# Record 186:
#      Data retrieved for Storslett, NO
# Record 187:
#      Data retrieved for Makat, KZ
# Record 188:
#      Data retrieved for Lorengau, PG
# Record 189:
#      Data retrieved for Garliava, LT
# Record 190:
#      Data retrieved for Coihaique, CL
# Record 191:
#      Data retrieved for Carnarvon, ZA
# Record 192:
#      Data retrieved for Banfora, BF
# Record 193:
#      Data retrieved for Haines Junction, CA
# Record 194:
#      Data retrieved for Sesimbra, PT
# Record 195:
#      Data retrieved for Heinola, FI
# Record 196:
#      Data retrieved for Svetlaya, RU
# Record 197:
#      Data retrieved for Champerico, MX
# Record 198:
#      Data retrieved for Coquimbo, CL
# Mys Shmidta cannot be found. Skipping to next city.
# Record 199:
#      Data retrieved for Jining, CN
# Record 200:
#      Data retrieved for Hithadhoo, MV
# Record 201:
#      Data retrieved for Codrington, AU
# Record 202:
#      Data retrieved for Vestmannaeyjar, IS
# Record 203:
#      Data retrieved for Nogales, US
# Record 204:
#      Data retrieved for San Jose, PH
# Record 205:
#      Data retrieved for Nikolskoye, RU
# Record 206:
#      Data retrieved for Lusambo, CD
# Record 207:
#      Data retrieved for Nurota, UZ
# Lolua cannot be found. Skipping to next city.
# Record 208:
#      Data retrieved for Meulaboh, ID
# Record 209:
#      Data retrieved for Mayumba, GA
# Bengkulu cannot be found. Skipping to next city.
# Record 210:
#      Data retrieved for Muros, ES
# Wanderlandia cannot be found. Skipping to next city.
# Haibowan cannot be found. Skipping to next city.
# Record 211:
#      Data retrieved for La Ronge, CA
# Record 212:
#      Data retrieved for Matveyev Kurgan, RU
# Record 213:
#      Data retrieved for Hay River, CA
# Record 214:
#      Data retrieved for Yulara, AU
# Record 215:
#      Data retrieved for Simao, CN
# Record 216:
#      Data retrieved for Zhigansk, RU
# Record 217:
#      Data retrieved for Khuzdar, PK
# Record 218:
#      Data retrieved for Butaritari, KI
# Barentsburg cannot be found. Skipping to next city.
# Record 219:
#      Data retrieved for Pacific Grove, US
# Record 220:
#      Data retrieved for Luanda, AO
# Record 221:
#      Data retrieved for Espumoso, BR
# Record 222:
#      Data retrieved for Letnyaya Stavka, RU
# Record 223:
#      Data retrieved for Baker City, US
# Record 224:
#      Data retrieved for Luderitz, NA
# Record 225:
#      Data retrieved for Port Lincoln, AU
# Record 226:
#      Data retrieved for Axim, GH
# Record 227:
#      Data retrieved for Barranca, PE
# Record 228:
#      Data retrieved for Shirokiy, RU
# Record 229:
#      Data retrieved for Gigmoto, PH
# Record 230:
#      Data retrieved for Novikovo, UA
# Rungata cannot be found. Skipping to next city.
# Record 231:
#      Data retrieved for Hasaki, JP
# Record 232:
#      Data retrieved for Portland, US
# Record 233:
#      Data retrieved for Thompson, CA
# Record 234:
#      Data retrieved for Buarcos, PT
# Record 235:
#      Data retrieved for Pangai, TO
# Record 236:
#      Data retrieved for Caravelas, BR
# Record 237:
#      Data retrieved for Soma, JP
# Kashi cannot be found. Skipping to next city.
# Record 238:
#      Data retrieved for Dingle, PH
# Record 239:
#      Data retrieved for Chanika, MW
# Record 240:
#      Data retrieved for Constitucion, MX
# Record 241:
#      Data retrieved for Palm Coast, US
# Record 242:
#      Data retrieved for Pula, EC
# Record 243:
#      Data retrieved for Kontagora, NG
# Record 244:
#      Data retrieved for Deputatskiy, RU
# Record 245:
#      Data retrieved for Baykit, RU
# Urumqi cannot be found. Skipping to next city.
# Record 246:
#      Data retrieved for Novoraychikhinsk, RU
# Record 247:
#      Data retrieved for Halifax, CA
# Record 248:
#      Data retrieved for Finspang, SE
# Record 249:
#      Data retrieved for Mezen, RU
# Record 250:
#      Data retrieved for Morondava, MG
# Record 251:
#      Data retrieved for Shiyan, CN
# Record 252:
#      Data retrieved for Manggar, ID
# Skagastrond cannot be found. Skipping to next city.
# Record 253:
#      Data retrieved for Cururupu, BR
# Record 254:
#      Data retrieved for Shenjiamen, CN
# Record 255:
#      Data retrieved for Great Yarmouth, GB
# Record 256:
#      Data retrieved for De Aar, ZA
# Record 257:
#      Data retrieved for Mangochi, MW
# Record 258:
#      Data retrieved for Havre-Saint-Pierre, CA
# Record 259:
#      Data retrieved for Beni Mazar, EG
# Record 260:
#      Data retrieved for Amapa, HN
# Record 261:
#      Data retrieved for Leningradskiy, RU
# Record 262:
#      Data retrieved for Seoul, KR
# Record 263:
#      Data retrieved for San Quintin, PH
# Jiddah cannot be found. Skipping to next city.
# Record 264:
#      Data retrieved for Kupang, ID
# Record 265:
#      Data retrieved for Daru, SL
# Record 266:
#      Data retrieved for Dudinka, RU
# Record 267:
#      Data retrieved for Ancud, CL
# Record 268:
#      Data retrieved for Kununurra, AU
# Record 269:
#      Data retrieved for Saskylakh, RU
# Record 270:
#      Data retrieved for Hendrina, ZA
# Record 271:
#      Data retrieved for Nikolsk, RU
# Record 272:
#      Data retrieved for Nanortalik, GL
# Record 273:
#      Data retrieved for Khandyga, RU
# Nizhneyansk cannot be found. Skipping to next city.
# Record 274:
#      Data retrieved for Nekrasovka, RU
# Record 275:
#      Data retrieved for Namibe, AO
# Record 276:
#      Data retrieved for Waipawa, NZ
# Record 277:
#      Data retrieved for Port Shepstone, ZA
# Record 278:
#      Data retrieved for Lasa, CY
# Record 279:
#      Data retrieved for Linjiang, CN
# Record 280:
#      Data retrieved for Aklavik, CA
# Record 281:
#      Data retrieved for Victor Harbor, AU

# %% [markdown]
# ### Pandas
# Use pandas to convert weather dictionary into data frame for analysis.

# %%
# convert city_data dict to pandas dataframe
city_df = pd.DataFrame(city_data)

#store weather variables for plotting
latitude = city_df.loc['Latitude']
longitude = city_df.loc['Longitude']
maximumtemp = city_df.loc['Max Temp F']
currenttemp = city_df.loc['Current Temp F']
cloudiness = city_df.loc['Cloudiness %']
humitidy = city_df.loc['Humitidy %']
windspeed = city_df.loc['Wind Speed']
country = city_df.loc['Country']

# %% [markdown]
# ### CSV File
# Save source data to csv file.

# %%
#create a dataframe to be saved to csv
city_csv = city_df

#clean dataframe
city_csv = city_csv.transpose()
city_csv = city_csv.reset_index()

#sort city names to be alphabetical
city_csv = city_csv.sort_values('index')
city_csv = city_csv.set_index('index')

#organize columns
city_csv = city_csv[['Country', 'Latitude','Longitude', 'Max Temp F', 'Current Temp F',
                     'Humitidy %','Cloudiness %','Wind Speed']]
#name index to "City"
city_csv.index.name = "City"

#export to CSV file
city_csv.to_csv('Data/CityData.csv')

# %% [markdown]
# ___
# ## Data Visualizations

# %% [markdown]
# ###  Temperatures
# #### Observations
# From the data, it appears clear that there is a relationship between the degrees latitude of the city and the temperature. That is, the closer a city gets to the equator (latitude = 0 degrees), the warmer the temperature. At the time the data was samples, the maximum temperatures occured within +/- 20 degrees of the equator.  The coldest temperatures were recorded at or near the north pole (latitude = 80 degrees).

# %%
#create scatter plot of current temperature using color mapping to show temperatures values
plt.scatter(latitude, currenttemp, c=currenttemp, alpha=.75, edgecolor='black', cmap='seismic')

#format grpah & save to file
plt.title(f'Current Temperature vs. City Latitude\nData current as of {api_end.strftime("%Y-%m-%d %H:%M")}')
plt.xlabel('Latitude')
plt.ylabel('Current Temperature (Farenheit)')
plt.grid(True)
plt.savefig('Figures/CurrentTemp.png')
plt.show()

# %%
#create scatter plot of longitude and latitude to map out cities, using current temp as color scale
plt.scatter(longitude, latitude, c=currenttemp, cmap='seismic', alpha=.75)

#format and save figure
plt.title(f'Current World Temperature Heat Map\nData as of {api_end.strftime("%Y-%m-%d %H:%M")}')
plt.xlabel('Degrees Longitude')
plt.ylabel('Degrees Latitude')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
xticks = np.arange(-180, 181, 30)
yticks = np.arange(-90, 91, 20)
plt.xticks(xticks)
plt.yticks(yticks)
          
#add equator
plt.axhline(y=0, alpha=.5, linestyle='--')
plt.text(-178, 2, '(Equator)')
          
#save figure
plt.savefig('Figures/WorldHeatMap.png')
plt.show()

# %% [markdown]
# ###  Humidity
# #### Observations
# Humidity percentage appears to be independent of the city latitude.  That is, there is at least 1 or more cities at most recordable latitudes that record 100% humitidy.  In general, the lower humidity areas appear to be just north of the equator (0 to 40 degrees).  Looking at humidity by location (world map), we get a sense of how each locations in each continent can impact humidity.  For example, the desert areas of Africa show very dry, but the coastal areas show more humid.

# %%
#create scatter plot of humidity using color mapping to show temperatures values
plt.scatter(latitude, humitidy, c=humitidy, alpha=.75, edgecolor='black', cmap='Reds')

#format grpah & save to file
plt.title(f'Humidity vs. City Latitude\nData Current as of {api_end.strftime("%Y-%m-%d %H:%M")}')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Humitidy Percentage')
plt.grid(True)
plt.ylim(-5, 105) #needed for bug where some cities show humidity of 300%
plt.savefig('Figures/Humidity.png')
plt.show()

# %%
#create scatter plot of longitude and latitude to map out cities, using current temp as color scale
plt.scatter(longitude, latitude, c=humitidy, cmap='Reds', alpha=.75)

#format and save figure
plt.title(f'Current World Temperature Humidity Map\nData as of {api_end.strftime("%Y-%m-%d %H:%M")}')
plt.xlabel('Degrees Longitude')
plt.ylabel('Degrees Latitude')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
xticks = np.arange(-180, 181, 30)
yticks = np.arange(-90, 91, 20)
plt.xticks(xticks)
plt.yticks(yticks)
          
#add equator
plt.axhline(y=0, alpha=.5, linestyle='--')
plt.text(-178, 2, '(Equator)')
          
#save figure
plt.savefig('Figures/WorldHeatMap.png')
plt.show()

# %% [markdown]
# ###  Cloud Coverage
# #### Observations
# Cloud percentage also appears to be indepedent of latitude.  Looking at the cloud percentage on the world map, it can be observed that certain regions might be more susceptible to cloud coverage.  For example, the pacific northwest to the Great Lakes of the US shows heavy cloud coverage.  It is important to note that since this is a "snapshot in time", these trend could change based on weather patterns or time of year.  For more accurate analysis, it would be advised to take multiple samples to complete the analysis.

# %%
#create scatter plot of cloud percentage using color mapping to show cloud % values on binary scale
plt.scatter(latitude, cloudiness, c=cloudiness, alpha=.75, edgecolor='black', cmap='Greys')

#format grpah & save to file
plt.title(f'Cloudiness vs. City Latitude\nData Current as of {api_end.strftime("%Y-%m-%d %H:%M")}')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Cloud Percentage')
plt.grid(True)
plt.savefig('Figures/Cloudiness.png')
plt.show()

# %%
#create scatter plot of longitude and latitude to map out cities, using current temp as color scale
plt.scatter(longitude, latitude, c=cloudiness, cmap='Greys', alpha=.75)

#format and save figure
plt.title(f'Current World Temperature Cloud Map\nData as of {api_end.strftime("%Y-%m-%d %H:%M")}')
plt.xlabel('Degrees Longitude')
plt.ylabel('Degrees Latitude')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
xticks = np.arange(-180, 181, 30)
yticks = np.arange(-90, 91, 20)
plt.xticks(xticks)
plt.yticks(yticks)
          
#add equator
plt.axhline(y=0, alpha=.5, linestyle='--')
plt.text(-178, 2, '(Equator)')
          
#save figure
plt.savefig('Figures/WorldCloudMap.png')
plt.show()

# %% [markdown]
# ###  WIndspeed
# #### Observations
# Windspeed, like cloud converage, is hard to analyze based on one time sample as in the study.  Futher, there does not appear to be any regional impact to wind speed.

# %%
#create scatter plot of windspeed using color mapping to show cloud % values on binary scale
plt.scatter(latitude, windspeed, c=windspeed, alpha=.95, edgecolor='black', cmap='Blues')

#format grpah & save to file
plt.title(f'Windspeed vs. City Latitude\nData Current as of {api_end.strftime("%Y-%m-%d %H:%M")}')
plt.xlabel('Latitude (degrees)')
plt.ylabel('Wind Speend (mph)')
plt.grid(True)
plt.savefig('Figures/WindSpeed.png')
plt.show()

# %%
#create scatter plot of longitude and latitude to map out cities, using current temp as color scale
plt.scatter(longitude, latitude, c=windspeed, cmap='Blues', alpha=.75)

#format and save figure
plt.title(f'Current World Temperature Wind Speed Map\nData as of {api_end.strftime("%Y-%m-%d %H:%M")}')
plt.xlabel('Degrees Longitude')
plt.ylabel('Degrees Latitude')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
xticks = np.arange(-180, 181, 30)
yticks = np.arange(-90, 91, 20)
plt.xticks(xticks)
plt.yticks(yticks)
          
#add equator
plt.axhline(y=0, alpha=.5, linestyle='--')
plt.text(-178, 2, '(Equator)')
          
#save figure
plt.savefig('Figures/WorldWindspeedMap.png')
plt.show()

# %% [markdown]
# ___
# ## Conclusions
# This project was an exercise in utlizing API data, along with python libraries, to collect and analyze real-world weather data.  First, random coordinates were generated using the numpy random function and zipped into coordinate pairs.  Then, the citipy library was used to determine the closest cities to the coordinate pairs.  Next, OpenWeatherMap API was scraped to collect weather data and stored into a dictionary.  Then, the weather dictionary was converted to a Pandas Data Frame.  Finally, the Data Frame was plotted using Plotly/Matplotlib.  Color Mapping was implimented to help visualize the data for various weather variables to determine trends.
